# %% [markdown]
# 1. [Parabola](#parabola)

# %% [markdown]
# #### Parabola:
# - it has a symmetric arc either in the four axes X & Y
# - consist of a focus point and a vertix
# - every point on the arc from the focus point is equidistant to the point on the directrix (axes parallel to the curve)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/parabola.jpeg')
new_image = img.resize((480, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=480x250>
