# %% [markdown]
# 1. [Hyperbola](#hyperbola)

# %% [markdown]
# #### Hyperbola:
# - consist of two symmetrical arcs opposite to one another
# - consists of focus points, vertix, co-vertix, traverse axis (through the arcs) and congugate axis (between the arcs)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/hyperbola.jpeg')
new_image = img.resize((550, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=CMYK size=550x250>
