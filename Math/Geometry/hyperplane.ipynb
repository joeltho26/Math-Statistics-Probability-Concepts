# %% [markdown]
# 1. [Hyperplane](#hyperplane)

# %% [markdown]
# #### Hyperplane:
# - is a generalization concept of planes for dimensions 3 or more in a space of more than 3D
# - planes: are two dimensional objects in 3D space, they are also considered as a surface which is flat in nature

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/hyperplane.jpeg')
new_image = img.resize((550, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=550x250>

# %% [markdown]
# - line: is a hyperplane 1 dimensional object which is represented in 2D space
# - point: is a hyperplane which is represented in 1D space
