# %% [markdown]
# 1. [Hypersurface](#Hypersurface)

# %% [markdown]
# #### Hypersurface:
# - generalization concept of surface for 3 dimensions and more in space more than 3D
# - surface: is a hypersurface 2D object in a 3D space

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/hypersurface.jpeg')
new_image = img.resize((480, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x250>

# %% [markdown]
# - curve: is a hypersurface 1D object in a 2D space
# - point: is a hypersurface object in 1D (so mostly surface is not associated with 1D)
