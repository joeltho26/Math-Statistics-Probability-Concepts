# %% [markdown]
# 1. [Gaussian Elimination & Row Echelon Form](#gaussian-elimination--row-echelon)

# %% [markdown]
# #### Gaussian Elimination & Row Echelon:
# - used to `solve` the `linear system of equations`
#     - i.e. finding the values of variables such as x, y, z
#
# Gaussian elimination for `X` & `Y` variables:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gaussian.png')
new_image = img.resize((650, 685))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=650x685>

# %% [markdown]
# Gaussian elimination for `X`, `Y` & `Z` variables:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gaussian3x3.png')
new_image = img.resize((700, 685))
display(new_image)

img = Image.open('images/gaussian3x3_1.png')
new_image = img.resize((600, 685))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=700x685>
# <PIL.Image.Image image mode=RGBA size=600x685>
