# %% [markdown]
# 1. [Order of Matrix](#order-of-matrix)

# %% [markdown]
# #### Order of Matrix:
# - talks about the rows and columns of a matrix
#     - eg: mxn: 2x4
#         - m = number of rows
#         - n = number of columns

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/order.png')
new_image = img.resize((285, 185))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=285x185>
