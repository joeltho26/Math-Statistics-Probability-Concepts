# %% [markdown]
# 1. [Trace of a Matrix](#trace-of-a-matrix)

# %% [markdown]
# #### Trace of a Matrix
# - calculated only for square matrix
# - the sum of the elements on its main diagonal

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/trace.jpg')
new_image = img.resize((305, 205))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=305x205>
