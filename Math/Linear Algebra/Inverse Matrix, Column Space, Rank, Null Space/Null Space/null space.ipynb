# %% [markdown]
# 1. [Null Space](#null-space)

# %% [markdown]
# #### Null Space or Kernel:
# - after ```transformation```, the ```vectors``` that get ```squished into the origin``` called Kernel or Null Space

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/nullspace.png')
new_image = img.resize((320, 285))
display(new_image)

img = Image.open('images/nullspace1.png')
new_image = img.resize((320, 285))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=320x285>
# <PIL.Image.Image image mode=RGBA size=320x285>
