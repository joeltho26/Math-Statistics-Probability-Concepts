# %% [markdown]
# 1. [Identity Matrix](#identity-matrix)

# %% [markdown]
# #### Identity Matrix:
# - the diagonal elements of a matrix = 1
# - square matrix

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/identity.png')
new_image = img.resize((145, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=145x150>
