# %% [markdown]
# 1. [Singular Matrix](#singular-matrix)

# %% [markdown]
# #### Singular Matrix:
# - square matrix
# - determinant = 0
# - inverse of the singular matrix is not possible
#
# Properties:
# - some rows and columns are linearly dependent

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/singular.png')
new_image = img.resize((395, 205))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=395x205>
