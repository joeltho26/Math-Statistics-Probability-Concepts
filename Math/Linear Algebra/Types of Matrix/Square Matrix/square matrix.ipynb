# %% [markdown]
# 1. [Square Matrix](#square-matrix)

# %% [markdown]
# #### Square Matrix:
# - `equal` number of `rows` and `columns` in a matrix i.e. 1x1, 2x2, 3x3, 4x4, etc
# - `square matrix transformation` i.e. `shear` or `rotation`

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/square.png')
new_image = img.resize((155, 145))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=155x145>
