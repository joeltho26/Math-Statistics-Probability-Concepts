# %% [markdown]
# 1. [Row Matrix](#row-matrix)

# %% [markdown]
# #### Row Matrix:
# - represented by single row

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/row.png')
new_image = img.resize((135, 85))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=135x85>
