# %% [markdown]
# 1. [Column Matrix](#column-matrix)

# %% [markdown]
# #### Column Matrix:
# - represented by single column

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/column.png')
new_image = img.resize((145, 145))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=145x145>
