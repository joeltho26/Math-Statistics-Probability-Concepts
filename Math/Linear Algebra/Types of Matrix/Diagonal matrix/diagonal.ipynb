# %% [markdown]
# 1. [Diagonal Matrix](#diagonal-matrix)

# %% [markdown]
# #### Diagonal Matrix:
# - when basis vectors are eigen vectors, we get diagonal matrix
# - square matrix
# - determinant of diagonal matrix = product of diagonal elements
# - Aᵀ = A
# - used to simplify complex calculations
# - used in eigenvalue and eigenvector analysis
# - mathematical operation:
#     - diagonal matrix multiplies a vector:
#         - scaling each component of the vector by the corresponding diagonal element
#     - matrix multiplication:
#         - multiply the corresponding diagonal elements
#     - Matrix inversion:
#         - reciprocal of each diagonal element

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/diagonal.png')
new_image = img.resize((250, 180))
display(new_image)

img = Image.open('images/diagonal2.png')
new_image = img.resize((220, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x180>
# <PIL.Image.Image image mode=RGBA size=220x120>
