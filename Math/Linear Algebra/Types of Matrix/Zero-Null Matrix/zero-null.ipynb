# %% [markdown]
# 1. [Zero/Null Matrix](#zeronull-matrix)

# %% [markdown]
# #### Zero/Null Matrix:
# - matrix with all `elements = 0`

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/zero.png')
new_image = img.resize((155, 135))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=155x135>
