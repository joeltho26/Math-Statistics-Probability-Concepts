# %% [markdown]
# 1. [Invertible Matrix](#invertible-matrix)

# %% [markdown]
# #### Invertible Matrix:
# - a square matrix
# - product of matrix A with inverse of A matrix results in an Identity Matrix
#     - `AA⁻¹ = I`
#
# Properties:
# - `AA⁻¹ = I`
# - determinant ≠ 0

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/invertible.png')
new_image = img.resize((390, 215))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=390x215>
