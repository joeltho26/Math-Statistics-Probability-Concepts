# %% [markdown]
# 1. [Vectors](#vectors)

# %% [markdown]
# #### Vectors:
#
# Link: https://www.3blue1brown.com/#lessons
#
# - represented in both `magnitude` and `direction`
# - can be represented in any number of dimension
#     - eg:
#         - 2D, 1x2 matrix
#         - 3D, 1x3 matrix
# - represented by an `arrow` above the variable
#     - eg: `V→`
# - vectors are associated with addition and scalar multiplication
# - `origin` is the `root/tail` of all vectors
#
# Note:
# - `Scalar`: only `magnitude`

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/vector2.png')
new_image = img.resize((210, 105))
display(new_image)

img = Image.open('images/vector1.png')
new_image = img.resize((250, 240))
display(new_image)

img = Image.open('images/vector3.png')
new_image = img.resize((350, 220))
display(new_image)

img = Image.open('images/coordinate-system.png')
new_image = img.resize((330, 180))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=210x105>
# <PIL.Image.Image image mode=RGBA size=250x240>
# <PIL.Image.Image image mode=RGBA size=350x220>
# <PIL.Image.Image image mode=RGBA size=330x180>
