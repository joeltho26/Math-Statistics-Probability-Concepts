# %% [markdown]
# 1. [Row Echelon Form](#row-echelon-form)

# %% [markdown]
# #### Row Echelon Form:
# - achieved using gaussian elimination
#
# Conditions:
# - All `nonzero rows` are `above` any `rows` of `all zeros`
# - The `leading coefficient` (also called the `pivot`) of a nonzero row is always strictly to the `right` of the `leading coefficient` of the `row above` it
# - `Controversial`: all the `pivot` values should be `1`

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/row-echelon1.png')
new_image = img.resize((170, 140))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=170x140>
