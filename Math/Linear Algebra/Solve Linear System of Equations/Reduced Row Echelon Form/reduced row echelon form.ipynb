# %% [markdown]
# 1. [Reduced Row Echelon Form](#reduced-row-echelon-form)

# %% [markdown]
# #### Reduced Row Echelon Form:
# - achieved using gaussian elimination
#
# Conditions:
# - follow row echelon form
# - the pivot (`leading coefficient`) values should always be `1`
# - if `pivot` present, only pivot value `1` should be available across the column of the matrix and remaining must be `0`

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/row-echelon.png')
new_image = img.resize((370, 190))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=370x190>
