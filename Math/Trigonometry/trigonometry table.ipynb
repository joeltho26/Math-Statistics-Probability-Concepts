# %% [markdown]
# 1. [Trigonometry Table](#trigonometry-table)

# %% [markdown]
# #### Trigonometry Table:
# - sinθ = opp/hyp
# - cosθ = adj/hyp
# - tanθ = sinθ/cosθ
# - cossecθ = 1/sinθ
# - secθ = 1/cosθ
# - cotθ = 1/tanθ

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/table.jpeg')
new_image = img.resize((630, 350))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=630x350>
