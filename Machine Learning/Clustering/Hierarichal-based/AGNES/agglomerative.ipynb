# %% [markdown]
# 1. [Agglomerative Approach](#agglomerative-approach)

# %% [markdown]
# #### Agglomerative Approach:
# - it is a type of hierarichal clustering
# - it is bottom to top approach
# - uses dendograms to identify the number of clusters
#
# Advantages:
# - small to medium datasets
# - when data has a hierarichal structure
# - when unknown cluster
#
# Disadvantages:
# - not used for large datasets
# - sensitive to outliers
# - sparse data
# - difficult handling different data types of data

# %% [markdown]
# - at first, we consider each data point as a cluster
# - then, we join the nearest data points and form that a new cluster
#     - the nearest points are calculated via distance metric
#         - euclidean
#         - manhattan
#         - minkowski
#         - jaccard
#         - cosine
#         - etc
# - we repeat the step of combining the sub clusters to form larger cluster
#     - to join 2 clusters to form a large cluster we can calculate the distances again
#         - nearest points or single linkage
#         - centroids of clusters
#         - farthest point in each cluster or complete linkage
#         - average of clusters or average linkage
#         - ward:
#             - minimize the total within cluster variance
#     - each of the linkage techniques has a cost value (δ) associated to it with a formula

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/dist.png')
new_image = img.resize((900, 470))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=900x470>

# %% [markdown]
# - we repeat until we only have 1 large cluster with all the data points in it, convergence as shown below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/agnes.jpg')
new_image = img.resize((900, 450))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=900x450>

# %% [markdown]
# - now, after the clusters are built, we create dendograms for the clusters formed
# - dendograms:
#     - vertical lines which combine based on the cluster distances
#     - each vertical line represents a data point or the sub clusters

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/dendogram.png')
new_image = img.resize((550, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=550x400>

# %% [markdown]
# - based on the threshold value either chosen or the value is evaluated based metrics

# %% [markdown]
# - the number of cluster are formed based on the number of vertical lines the threshold value has cut horizontally
#     - below image shows the threshold cut and the number of clusters = 2

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/threshold.png')
new_image = img.resize((550, 450))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=550x450>
