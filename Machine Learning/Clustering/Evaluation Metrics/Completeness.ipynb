# %% [markdown]
# 1. [Completeness](#completeness)

# %% [markdown]
# #### Completeness:
# - measure if all the members of the class is present in the cluster
# - the higher the better

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/complete.png')
new_image = img.resize((170, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=170x90>
