# %% [markdown]
# 1. [v-measure score](#v-measure-score)

# %% [markdown]
# #### v-measure score:
# - harmonic mean of homogenity and completeness
# - comparing both the ground truth and the prediction of algorithm
# - β = weight

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/vmeasure.png')
new_image = img.resize((480, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=480x80>
