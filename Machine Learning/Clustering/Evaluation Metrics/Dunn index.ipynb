# %% [markdown]
# 1. [Dunn Index](#dunn-index)

# %% [markdown]
# #### Dunn Index:
# - measure the distance between the formed cluster and ensure they are far apart
# - min distance between points in the inter cluster/max distance between points in intra cluster
# - higher the value, the better

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/dunn.png')
new_image = img.resize((320, 110))
display(new_image)

from PIL import Image 
from IPython.display import display

img = Image.open('images/dunn1.png')
new_image = img.resize((320, 70))
display(new_image)


from PIL import Image 
from IPython.display import display

img = Image.open('images/dunn2.png')
new_image = img.resize((270, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=320x110>
# <PIL.Image.Image image mode=RGBA size=320x70>
# <PIL.Image.Image image mode=RGBA size=270x80>
