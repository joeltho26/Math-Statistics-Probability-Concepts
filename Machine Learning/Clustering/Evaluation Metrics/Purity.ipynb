# %% [markdown]
# 1. [Purity](#purity)

# %% [markdown]
# #### Purity:
# - measure the purity of clustered data points
# - ratio of correctly clustered points by the overall data points
# - ranges: 0 - 1
# - the higher the value, the better

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/purity.png')
new_image = img.resize((400, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x90>
