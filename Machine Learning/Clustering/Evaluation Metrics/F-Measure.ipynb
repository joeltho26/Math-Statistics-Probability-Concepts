# %% [markdown]
# 1. [F-measure](#f-measure)

# %% [markdown]
# #### F-measure:
# - harmonic mean of precision and recall
# - compares the clustering of data points between ground truth and predicted cluster of the algorithms

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/f-measure.png')
new_image = img.resize((450, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x90>
