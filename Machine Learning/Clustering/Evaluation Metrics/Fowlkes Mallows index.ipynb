# %% [markdown]
# 1. [Fowlkes–Mallows Index](#fowlkesmallows-index)

# %% [markdown]
# #### Fowlkes–Mallows Index:
# - evaluates the clusters formed
# - the higher the value, the better
# - compares ground truth and predicted algorithm
# - the geometric mean of precision and recall

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/foulkes.png')
new_image = img.resize((350, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x90>
