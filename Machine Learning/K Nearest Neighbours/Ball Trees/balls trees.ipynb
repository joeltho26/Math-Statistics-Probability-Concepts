# %% [markdown]
# 1. [Ball Trees](#ball-trees)

# %% [markdown]
# #### Ball Trees:
# - used in KNN for both classification and regression problem statement
# - used to find the K-nearest neighbours in multiple dimensions
# - performs better if the data points are in higher dimensions and sparsely distributed

# %% [markdown]
# ##### Process of Ball Tree:
# - now consider the list of data points plotted in a 2D graph
# - we choose a random data point from the graph but ensure the data point is an already existing data point
#     - (5,6)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - now from the random data point, choose the data point farthest from it
#     - (1,2) => 5.66

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt1.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - now consider the farthest point from (1,2)
#     - (7,8) => 8.49

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt2.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - now connect the 2 farthest dots and then project all the data point onto it

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt3.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - calculate the mean value of the data point on the line and draw a split line

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt4.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - calculate the centroid for each of the split separately

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt5.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - now take the data point farthest from the centroid and draw a circle with centroid as the center on both sides of the splits

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt6.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - Summarizing the entire process, at first we begin with one big circle with all data points in it and then we perform the above procedure to create hyperspheres on both sides of the split

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt7.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - we repeat creating hypersheres until the below graph

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt8.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - now if we want to find the query point belonging to which group as shown below
# - we check the shortest distance from each of the centroids i.e. ball 6 & 7
#     - we find ball 6 centroid is closer => 2.1

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt9.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x400>

# %% [markdown]
# - now we choose the data points withint ball six and again calculate the distance between the query data point and the data points within the ball 6 => 2

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt10.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=480x400>

# %% [markdown]
# - now we know the data point (8,3) is the nearest neighbor to the data point (8,5)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bt11.png')
new_image = img.resize((480, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=480x400>

# %% [markdown]
# - likewise, we can choose the nearest neighbours based on the K value and produce the output for regression and classification problems
