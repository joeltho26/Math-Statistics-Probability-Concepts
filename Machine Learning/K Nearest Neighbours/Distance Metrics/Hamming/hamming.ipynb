# %% [markdown]
# 1. [Hamming Distance](#hamming-distance)

# %% [markdown]
# #### Hamming Distance:
# - used to calculate the ```distance/dissimilarities between two words or binary strings``` of  ```equal length```
# - quantifies the ```differences``` based on comparing each ```character position``` of the strings
# - used in Natural Language Processing

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/hamming.jpg')
new_image = img.resize((400, 210))
display(new_image)
# Out:
# <PIL.Image.Image image mode=CMYK size=400x210>
