# %% [markdown]
# 1. [Haversine Distance](#haversine-distance)

# %% [markdown]
# #### Haversine Distance:
# - used to calculate ```distance between 2 points on a curved surface```

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/haversine.avif')
new_image = img.resize((400, 310))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x310>
