# %% [markdown]
# 1. [Euclidean Distance](#euclidean-distance)

# %% [markdown]
# #### Euclidean Distance:
# - used to calculate the ```shortest distance between 2 points```
# - used in several ML algorithms and statistics to calculate the distances between 2 vectors
# - Euclidean Distance formula shown below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/euclidean.png')
new_image = img.resize((400, 210))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x210>
