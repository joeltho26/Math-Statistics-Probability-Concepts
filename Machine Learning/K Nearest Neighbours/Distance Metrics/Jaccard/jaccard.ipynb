# %% [markdown]
# 1. [Jaccard Distance](#jaccard-distance)

# %% [markdown]
# #### Jaccard Distance:
# - it used to calculate the ```dissimilarities/distance between 2 sets of items, words, labels, etc```
# - also called as ```Jaccard similarity```
# - used in Natural Language Processing
# - known as intersection over union of sets

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/jaccard.png')
new_image = img.resize((600, 320))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x320>
