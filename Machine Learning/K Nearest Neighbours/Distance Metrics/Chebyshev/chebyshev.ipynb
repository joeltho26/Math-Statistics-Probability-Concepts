# %% [markdown]
# 1. [Chebyshev Distance](#chebyshev-distance)

# %% [markdown]
# #### Chebyshev Distance:
# - used to calculate the ```maximum distance between 2 points``` either in ```horizontal or vertical axis```

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/chebyshev.png')
new_image = img.resize((250, 30))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x30>
