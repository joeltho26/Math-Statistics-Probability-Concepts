# %% [markdown]
# 1. [Levenshtein Distance](#levenshtein-distance)

# %% [markdown]
# #### Levenshtein Distance:
# - used to calculate the ```distance/dissimilarities between 2 strings``` of ```unequal length```
# - quantifies the difference based on number of ```character edits, insertions, deletions or substitutions```
# - used in Natural Language Processing

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/levenshtein.png')
new_image = img.resize((600, 260))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x260>
