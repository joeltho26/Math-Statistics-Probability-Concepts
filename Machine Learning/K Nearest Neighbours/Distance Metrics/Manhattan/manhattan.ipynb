# %% [markdown]
# 1. [Manhattan Distance](#manhattan-distance)

# %% [markdown]
# #### Manhattan Distance:
# - used to ```calculate distance between 2 points```
# - distance calculation moves either ```vertical``` or ```horizontal``` and not diagonal
# - eg: ```chess board```, ```city block```, etc

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/manhattan.png')
new_image = img.resize((400, 260))
display(new_image)

img = Image.open('images/manhattan1.jpg')
new_image = img.resize((400, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=400x260>
# <PIL.Image.Image image mode=RGB size=400x100>
