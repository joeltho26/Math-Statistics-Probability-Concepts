# %% [markdown]
# 1. [Non-Linear SVM](#non-linear-svm)

# %% [markdown]
# #### Non-Linear SVM:
# - when data points are non linear in nature

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/nsvm.png')
new_image = img.resize((490, 40))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=490x40>

# %% [markdown]
# - to perform support vector classifier on non linear data
#     - we need to increase the dimensions of data
#     - calculate the relationship between each datapoints
#     - then choose the support vector classifier to separate the classes
#         - the support vector classifier is evaluated as the same as linear SVM

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/high_dimension.png')
new_image = img.resize((510, 350))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=510x350>

# %% [markdown]
# - to increase the dimensions and choose the support vectors classifier, we need kernels
# - Kernels
#     - Polynomial
#     - Sigmoid
#     - Radial Basis Function
#     - Linear

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/svm.png')
new_image = img.resize((500, 340))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x340>

# %% [markdown]
# - support vector classifier with margins

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/support_vector_classifier2.png')
new_image = img.resize((500, 340))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x340>

# %% [markdown]
# - when we have 3 or more dimensions, create the hyperplanes

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/support_vector_classifier3.png')
new_image = img.resize((580, 340))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=580x340>

# %% [markdown]
# - the kernels will calculate the relationship between each data points and chose the appropriate support vector classifier

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/relationship.png')
new_image = img.resize((510, 360))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=510x360>

# %% [markdown]
# - now consider, we have feature with binary output values in a 3d space
# - to make the predictions for Linear SVM soft classifier shown below
#     - αi = weights of the data points
#     - yi = observed value
#     - b = bias
#     - K(xnew . xi) = kernel function which measures similarity between new data point multiplied with support vector
#         - xi = support vectors
#     - nsu = number of support vectors

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/pred.png')
new_image = img.resize((450, 145))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x145>

# %% [markdown]
# - ellaborating the above formula will become similar to the one shown below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/pred4.png')
new_image = img.resize((840, 105))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=840x105>

# %% [markdown]
# - prediction is very similar to regression for non linear svr
