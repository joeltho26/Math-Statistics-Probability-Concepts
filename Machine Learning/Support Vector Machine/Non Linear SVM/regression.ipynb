# %% [markdown]
# 1. [Non Linear SVR](#non-linear-svr)

# %% [markdown]
# #### Non Linear SVR:
# - to perform support vector classifier on non linear data
#     - we need to increase the dimensions of data
#     - calculate the relationship between each datapoints
#     - then choose the support vector classifier to separate the classes
#         - the support vector classifier is evaluated as the same as linear SVM

# %% [markdown]
# - to increase the dimensions and choose the support vectors classifier, we need kernels
# - Kernels
#     - Polynomial
#     - Sigmoid
#     - Radial Basis Function
#     - Linear

# %% [markdown]
# - now consider, we have feature with binary output values in a 3d space
# - to make the predictions for Linear SVM soft classifier shown below
#     - αi = weights of the data points
#     - b = bias
#     - K(xi . x) = kernel function which measures similarity between new data point multiplied with support vector
#         - x = new data point
#         - xi = support vectorss

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/pred3.png')
new_image = img.resize((400, 95))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x95>

# %% [markdown]
# - now lets consider an example with prediction of SVR for non linear use case:
# - support vectors:
#     - x_1 = [1.5, 2]
#     - x_2 = [2.0, 1]
#     - x_3 = [2.5, 3]
# - Lagrange Multipliers (α_i - α_i*) also known as weights
#     - α_1 - α_1* = 0.2
#     - α_2 - α_2* = -0.5
#     - α_3 - α_3* = 0.3
# - Bias (b): b = 1.0
# - RBF Kernel Parameter (γ): γ = 0.5
# - choosing RBF kernel
#     - K(x, x_i) = exp(-γ * ||x - x_i||^2)
#         - x is the new input data point.
#         - x_i is a support vector.
#         - ||x - x_i||^2 is the squared Euclidean distance between x and x_i.
#         - γ is the kernel parameter.

# %% [markdown]
# - now to predict the new house value
#     - x_new: x1 = 2.2, x2 = 1.8
# - before calculating the prediction value
# - calculate Kernel Values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/kernel_calc.png')
new_image = img.resize((400, 395))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x395>

# %% [markdown]
# - using the above prediction formula
#     - f(x_new) = Σ (α_i - α_i*) * K(x_new, x_i) + b
#     - f(x_new) = (0.2 * 0.767) + (-0.5 * 0.712) + (0.3 * 0.465) + 1.0 = 0.1534 - 0.356 + 0.1395 + 1.0 = 0.9369
