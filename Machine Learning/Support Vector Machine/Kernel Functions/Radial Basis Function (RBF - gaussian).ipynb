# %% [markdown]
# 1. [Radial Basis Function](#radial-basis-function)

# %% [markdown]
# #### Radial Basis Function:
# - used to not move the data points from a lower dimension to higher dimension
# - used to calculate the relationship between each data points and choose the support vector classifier in infinite dimensions
# - uses the kernel trick
#     - calculates the relationship between data points without transforming the data points into higher dimensions
# - performs like a Weighted Nearest Neighbor model
#     - data points nearer will have more influence than the data points far away from it

# %% [markdown]
# - the formula for radial basis is shown below
# - since the radial basis works with dimensions in infinite dimesions, its diffcult to visualize it
#
# consider the example:
# - γ = 1/2

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/radial.png')
new_image = img.resize((770, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=770x200>

# %% [markdown]
# - γ = used to scale the distance of influence and chosen via cross validation
#
# To visualize the working of RBF, we consider the Polynomial Function with r = 0 with varying degree values
# - d = 2, (a^2) . (b^2)
# - d = 3, (a^3) . (b^3)
# - d = 4, (a^4) . (b^4)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/rbf_eg.png')
new_image = img.resize((570, 70))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=570x70>

# %% [markdown]
# - now by adding the polynomial function for d = 1 & 2 values, we get the dot product values in 2-dimension

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/rbf_add.png')
new_image = img.resize((360, 75))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=360x75>

# %% [markdown]
# - now by adding the polynomial function for d = 1, 2 & 3 values, we get the dot product values in 3-dimension

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/rbf_add2.png')
new_image = img.resize((500, 60))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x60>

# %% [markdown]
# - now combining the polynomial functions upto infinity

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/rbf_add3.png')
new_image = img.resize((800, 60))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x60>

# %% [markdown]
# - now expanding the rbf formula with r = 1/2

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/rbf_add4.png')
new_image = img.resize((700, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=700x90>

# %% [markdown]
# - we can create the taylor series expansion of the last term

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor_series.png')
new_image = img.resize((800, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x80>

# %% [markdown]
# - the derivative of e^x = e^x itself

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor_series1.png')
new_image = img.resize((800, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x120>

# %% [markdown]
# - now, if a = 0

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor_series2.png')
new_image = img.resize((750, 110))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=750x110>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor_series3.png')
new_image = img.resize((850, 240))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=850x240>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor_series4.png')
new_image = img.resize((900, 230))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=900x230>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor_series5.png')
new_image = img.resize((1050, 140))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=1050x140>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor_series6.png')
new_image = img.resize((220, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x80>
