# %% [markdown]
# 1. [Homoskedasticity vs Hetroskedasticity](#homoskedasticity-vs-hetroskedasticity)

# %% [markdown]
# #### Homoskedasticity vs Hetroskedasticity:
#
# Homoskedasticity:
# - the variance of error is constant with change in the independent variables
#
# Hetroskedasticity:
# - the variance of error is not constant with change in the independent variables

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/homovshetro.png')
new_image = img.resize((760, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=760x300>
