# %% [markdown]
# 1.[Simple Linear Regression](#simple-linear-regression)

# %% [markdown]
# #### Simple Linear Regression:
# - used to perform prediction for regression problem statement
# - represented by the equation of a straight line
# - Overfitting:
#     - when the sample used for training and building the best fit line is small
# - Undefitting:
#     - when the data in non linear
#     - when the model is not fit with the best fit
#     - outliers present in the data

# %% [markdown]
# - here in simple linear regression, we have one independent variables (feature) and 1 target variable used to perform prediction
# - since the linear regression is denoted by equation of a straight line
#     - the formula for a straight line is y = mx + c
#         - y => dependent variable
#         - m => slope
#             - unit change in y (dependent variable) w.r.t to 1 unit change in x-axis (independent variable)
#         - x => independent variable
#         - c => intercept
#             - the point at which the linear regression line that intercept the y-axis, when the independent value is 0

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/slope_intercept.png')
new_image = img.resize((350, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=350x300>

# %% [markdown]
# - we use the ordinary least squared method to find the best fit line for linear regression
#     - Ordinary Least Square:
#         - we calculate the sum of squared distance between the predicted line and the data points known as errors
#         - we make sure, we choose the best fitting line which has the lowest sum of square residuals calculated via cost function
#             - cost function = 1/2 * Σ (y-y^)^2

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/fit_line.png')
new_image = img.resize((350, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x300>

# %% [markdown]
# - we perform the least square to find the best fitting line with different values for slope and intercept
# - At first, we take the mean of the dependent variable and start fitting the line perpendicular to the y-axis

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/fit_line3.png')
new_image = img.resize((350, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x300>

# %% [markdown]
# - now, we step by step chosing varying values for slope and intercept to find the best fitting line

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/fit_line2.png')
new_image = img.resize((350, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x300>

# %% [markdown]
# - if we plot the residual sum of squared against each rotation of the line, we will get the gradient descent

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gd.png')
new_image = img.resize((350, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x300>

# %% [markdown]
# - but, we need a convergence algorithm for the varying values of slope and intercept otherwise if the varying values of slope and intercept are higher or very small in nature
#     - the data points in the above gradient descent graph will be either jumping all over the global minima or move very slowly towards global minima

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/conv.png')
new_image = img.resize((320, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=320x200>

# %% [markdown]
# - we take the first order derivative with the cost function w.r.t slope and intercept values as shown above
#     - θj is one of the co-ordinated, we are adjusting to get to global minima
#     - we are calculating the slope for the datapoint in the gradient descent curve by taking the tangent as shown below
#     - the gradient descent convergence algorithm also has a learning rate (α)
#         - α = size of each step

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gd1.png')
new_image = img.resize((350, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x300>

# %% [markdown]
# - now, we look at the right side of the tangent line and confirm if it positive or negative slope
#     - the right side of the tangent line point downwards, then its called negative slope
#     - the right side of the tangent line point upwards, then its called positive slope
# - repeat the steps above until we reach convergence i.e. reach global minima

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gd2.png')
new_image = img.resize((350, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x300>

# %% [markdown]
# - to find the performance of the model, we use R squared
#     - how well the independent variables explain variation of dependent variable
#     - the goodness of fit
# - the formula for R-squared
#     - R2 = 1 - (RSS/TSS)
#         - RSS => residual sum of squares i.e. the residuals from the fit line to the data points
#         - TSS => residuals sum of squares from the mean of the target variable

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/fit_line.png')
new_image = img.resize((350, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x300>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/fit_line3.png')
new_image = img.resize((350, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x300>

# %% [markdown]
# - R2 value is calculated for simple linear regression but not for multiple linear regression problem
#     - we used adjusted R2 for multiple linear regression because as the number of the variables increase the R2 value also increases irrespective of it contribution of explaining the variation of data
# - now, we need to find if the R2 value is statistically significant or not
#     - the formula for P-value shown below
#         - Pfit = number of coefficient including the intercept, since simple linear regression RSS = 2
#         - Pmean = only the intercept in TSS = 1

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/pvalue.png')
new_image = img.resize((380, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x80>

# %% [markdown]
# - if the fit is good, the F value will be large
# - now to convert the F value into a P-value
# - consider n number of random dataset and calculate the F-value respectively for them
# - this will create histogram
#     - x-axis = F-values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/pvalue1.png')
new_image = img.resize((380, 340))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x340>

# %% [markdown]
# - now we take the original dataset and calculate the F-values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/pvalue2.png')
new_image = img.resize((380, 350))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x350>

# %% [markdown]
# - we draw a line over the histrogram to calculate the p-value

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/pvalue3.png')
new_image = img.resize((420, 350))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=420x350>
