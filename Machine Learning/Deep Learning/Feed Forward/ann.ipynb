# %% [markdown]
# 1. [Feed Forward Neural Network](#feed-forward-neural-network)

# %% [markdown]
# #### Feed Forward Neural Network:
# - the product of weights and the input along with bias is given to the hidden layers in the neural network which consist of an activation function which enables the neurons in the hidden layers to be fired or activated
# - the activated neurons will help in the prediction of the output label/values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/ann.png')
new_image = img.resize((500, 270))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x270>
