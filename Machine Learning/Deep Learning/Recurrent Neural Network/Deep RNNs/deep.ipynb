# %% [markdown]
# 1. [Deep RNN](#deep-rnn)

# %% [markdown]
# #### Deep RNN:
# - here in deep RNN, we use multiple RNNs layered one top of the other
# - it is used to identify complex relationship and predict the output

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/deep.png')
new_image = img.resize((900, 430))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=900x430>
