# %% [markdown]
# 1. [Bi-directional RNN](#bi-directional-rnn)

# %% [markdown]
# #### Bi-directional RNN:
# - here the in the bi-directional RNN, we fit an RNN in both the forward and backward direction
# - it used both before and after words for the prediction of output
# - it performs better than a vanilla RNN
# - it is computationally intensive and has slow training process

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bi-rnn.png')
new_image = img.resize((600, 330))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x330>
