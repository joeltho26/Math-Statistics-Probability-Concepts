# %% [markdown]
# 1. [Nesterov Accelerated Gradient](#nesterov-accelerated-gradient)

# %% [markdown]
# #### Nesterov Accelerated Gradient:
# - it is an extension of SGD with momentum with same parameters
# - it has an improved performance to the optimization process by overcoming the overshooting problem
# - it calculates the gradient not at the current step instead the look ahead step and apply momentum

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/nesterov.png')
new_image = img.resize((690, 380))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=690x380>
