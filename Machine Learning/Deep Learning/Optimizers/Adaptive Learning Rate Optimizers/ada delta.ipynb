# %% [markdown]
# 1. [AdaDelta](#adadelta)

# %% [markdown]
# #### AdaDelta:
# - it is an improvization of rmsprop which eliminates the need for manually assigning a global learning rate

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/adagrad.png')
new_image = img.resize((390, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=390x250>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/adadelta1.png')
new_image = img.resize((270, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=270x200>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/adadelta2.png')
new_image = img.resize((270, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=270x100>
