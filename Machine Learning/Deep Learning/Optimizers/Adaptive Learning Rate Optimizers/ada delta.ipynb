# %% [markdown]
# 1. [AdaDelta](#adadelta)

# %% [markdown]
# #### AdaDelta:
# - this overcomes the issue related to adagrad i.e. high "αt" value resulting in very low "η`" rotating learning rate value thus increasing the iteration time
# - adadelta uses exponential weighted average by using the momentum coefficient

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/adagrad.png')
new_image = img.resize((390, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=390x250>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/adagrad1.png')
new_image = img.resize((270, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=270x250>

# %% [markdown]
# - the adadelta has a variation while calculating the "αt" value  as shown below
#     - the best γ value chosen usually 0.95

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/adadelta.png')
new_image = img.resize((490, 160))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=490x160>

# %% [markdown]
# - by this, we are restricting the "αt" value to a certain value and not letting the "η`" value to decrease rapidly
