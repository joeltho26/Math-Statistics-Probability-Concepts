# %% [markdown]
# 1. [Mini Batch Stochastic Gradient Descent](#mini-batch-stochastic-gradient-descent)

# %% [markdown]
# #### Mini Batch Stochastic Gradient Descent:
# - a small set 'K' of data points or records are chosen in each instance to perform back propogation and update the weights in a neural network
# - we will encounter noise and the time take to reach global minima is greater than the gradient descent approach

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gd.png')
new_image = img.resize((300, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300>
