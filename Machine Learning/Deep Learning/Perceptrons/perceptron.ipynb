# %% [markdown]
# 1. [Perceptron](#perceptron)

# %% [markdown]
# #### Perceptron:
# - its one of the first deep learning technique in ML
# - it used a summing function which sums the product of weights and the inputs and then it is given to the activation function
# - the activation function gives out the output

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/perceptron.png')
new_image = img.resize((650, 330))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=650x330>
