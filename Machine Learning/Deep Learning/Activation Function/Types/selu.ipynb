# %% [markdown]
# 1. [Scaled Exponential Function](#scaled-exponential-function)

# %% [markdown]
# #### Scaled Exponential Function:
# - it is a variant pf exponential linear unit
# - the values ranges are very similar to ELU
# - this activation function very similar to ELU except there is a λ which is multiplied with the values of the ELU
# - used in deep neural networks
# - it has a self normalizing property

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/selu1.png')
new_image = img.resize((400, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=400x80>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/selu.png')
new_image = img.resize((600, 320))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=600x320>
