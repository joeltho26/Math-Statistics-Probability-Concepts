# %% [markdown]
# 1. [Binary Function](#binary-function)

# %% [markdown]
# #### Binary Function:
# - the values for binary function ranges as either 0 or 1
# - the binary function used in the output layer of neural network

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/binary.png')
new_image = img.resize((200, 130))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=200x130>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/binary1.png')
new_image = img.resize((300, 320))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x320>
