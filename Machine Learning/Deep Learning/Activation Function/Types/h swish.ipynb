# %% [markdown]
# 1. [H Swish Function](#h-swish-function)

# %% [markdown]
# #### H Swish Function:
# - it is called as Hard Swish function
# - since regular swiss function is computationally intensive, we introduced h swish which is computationally faster
# - the working of h swish function is the smae as regular swish function however it uses relu6 activation function

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/hswish.png')
new_image = img.resize((400, 280))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x280>
