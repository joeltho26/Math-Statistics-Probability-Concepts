# %% [markdown]
# 1. [Relu6 Function](#relu6-function)

# %% [markdown]
# #### Relu6 Function:
# - it is a variety from the RELU function
# - the ranges of relu6 is between 0 to +6, i.e. any value less than 0 will become 0 and any value greater than 6 will become 6 and any values between 0-6 will be the value itself
# - the derivative value will result in value 1 when the values are between 0-6 and if the values outside of the range will result in 0
# - dying relu problem exists

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/relu61.png')
new_image = img.resize((400, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=400x250>
