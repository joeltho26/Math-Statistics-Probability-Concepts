# %% [markdown]
# 1. [Leaky Relu Function](#leaky-relu-function)

# %% [markdown]
# #### Leaky Relu Function:
# - the values ranges between small negative values to positive values
# - the derivative of leaky relu ranges between very small positive values closer to 0 to positive values
# - overcomes the dead activation function or dying relu problem
# - the values are not zero centered

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/lrelu1.png')
new_image = img.resize((250, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=250x100>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/lrelu.png')
new_image = img.resize((450, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x250>
