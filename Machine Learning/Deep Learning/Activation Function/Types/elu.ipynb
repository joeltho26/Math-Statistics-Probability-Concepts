# %% [markdown]
# 1. [ELU Function](#elu-function)

# %% [markdown]
# #### ELU Function:
# - it is called as Exponential Linear Unit
# - the ranges of ELU function is between small negative value to positive value
# - the range of derivative of ELU function is between small positive value to 1
# - overcome dyling relu problem
# - values of ELU are not zero centered

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/elu.png')
new_image = img.resize((360, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=360x120>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/elu1.png')
new_image = img.resize((400, 320))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=400x320>
