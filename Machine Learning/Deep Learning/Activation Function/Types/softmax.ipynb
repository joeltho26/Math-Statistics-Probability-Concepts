# %% [markdown]
# 1. [Softmax Function](#softmax-function)

# %% [markdown]
# #### Softmax Function:
# - it is used in the output layer to predict multi-class outputs
# - the values for softmax function ranges between 0 - positive value (like and exponential curve)
# - the derivative value for softmax ranges between 0 - 0.25

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/softmax.png')
new_image = img.resize((200, 140))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=200x140>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/softmax1.png')
new_image = img.resize((400, 320))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x320>
