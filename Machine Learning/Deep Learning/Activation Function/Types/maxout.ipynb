# %% [markdown]
# 1. [MaxOut Function](#maxout-function)

# %% [markdown]
# #### MaxOut Function:
# - its a learnable activation function
# - it majorily contributes in improving the effectiveness of dropout regularization
# - it is computationally intensive
# - other learnable activation functions are SLAF, Meta ACON, APL, L Sigmoid, PRelu, Harmonic functions, etc
# - learnable activation functions helps us to improve the performance of the neural network and its prediction
# - it is used when there is complex relationship between data

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/maxout.png')
new_image = img.resize((400, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x100>
