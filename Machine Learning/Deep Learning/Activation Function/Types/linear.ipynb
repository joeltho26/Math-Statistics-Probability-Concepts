# %% [markdown]
# 1. [Linear Function](#linear-function)

# %% [markdown]
# #### Linear Function:
# - it is used when there is a regression output value to be predicted
# - the values of linear activation function ranges between negative values to positive values
# - the values of derivative of linear activation function is 1 for all values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/linear1.jpeg')
new_image = img.resize((150, 50))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=150x50>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/linear.png')
new_image = img.resize((600, 270))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=600x270>
