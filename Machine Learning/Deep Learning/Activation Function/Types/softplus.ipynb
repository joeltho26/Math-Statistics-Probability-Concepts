# %% [markdown]
# 1. [Softplus Function](#softplus-function)

# %% [markdown]
# #### Softplus Function:

# %% [markdown]
# - it is used in hidden layers of the neural network
# - the values of softplus function ranges between 0 to positive values
# - the values of derivative of softplus function ranges between 0 - 1
# - overcomes vanishing gradient problem
# - overcomes dying relu problem

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/softplus1.png')
new_image = img.resize((220, 40))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x40>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/softplus.png')
new_image = img.resize((600, 280))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=600x280>
