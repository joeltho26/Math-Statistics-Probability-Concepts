# %% [markdown]
# 1. [Vanilla Autoencoder](#vanilla-autoencoder)

# %% [markdown]
# #### Vanilla Autoencoder:
# - its the simplest and most common type of auto encoders
# - here the latent space or the bottleneck layer has lesser neurons than the input
# - forces the encoder to learn a compressed representation of the most important features
# - used for dimensionality reduction

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/latent.png')
new_image = img.resize((690, 350))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=690x350>
