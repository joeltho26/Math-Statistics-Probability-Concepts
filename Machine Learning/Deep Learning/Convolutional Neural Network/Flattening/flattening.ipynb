# %% [markdown]
# 1. [Flattening](#flattening)

# %% [markdown]
# #### Flattening:
# - it is performed after the pooling layer and before the fully connected layer
# - converts the data from a multi dimensional output matrix to a 1 dimensional array vector

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/flatten.png')
new_image = img.resize((600, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x300>
