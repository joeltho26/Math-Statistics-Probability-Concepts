# %% [markdown]
# 1. [Box Blur](#box-blur)

# %% [markdown]
# #### Box Blur:
# - box blur uses a simple average of neighboring pixel values, which can appear more pixelated or blocky.

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/filters.png')
new_image = img.resize((350, 610))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x610>
