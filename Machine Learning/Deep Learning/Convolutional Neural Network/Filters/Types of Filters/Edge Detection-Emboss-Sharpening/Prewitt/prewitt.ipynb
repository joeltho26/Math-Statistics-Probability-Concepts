# %% [markdown]
# 1. [Prewitt Filters](#prewitt-filters)

# %% [markdown]
# #### Prewitt Filters:
# - they are edge detection filters which capture information around the edges of an image
# - there are vertical and horizontal filters

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/prewitt.png')
new_image = img.resize((370, 160))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=370x160>
