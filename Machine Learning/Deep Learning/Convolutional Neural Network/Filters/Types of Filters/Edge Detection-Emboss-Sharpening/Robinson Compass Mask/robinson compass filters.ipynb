# %% [markdown]
# 1. [Robinson Compass Mask](#robinson-compass-mask)

# %% [markdown]
# #### Robinson Compass Mask:
# - it uses compass directions to generate feature map (convolutions)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/robinson.png')
new_image = img.resize((570, 260))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=570x260>
