# %% [markdown]
# 1. [2D Convolution](#2d-convolution)

# %% [markdown]
# #### 2D Convolution:
# - here the filters used will be 2x2 kernels but the filters are 3x3

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/kernels.png')
new_image = img.resize((370, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=370x300>
