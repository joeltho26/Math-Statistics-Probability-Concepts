# %% [markdown]
# 1. [Deformed Convolutions](#deformed-convolutions)

# %% [markdown]
# #### Deformed Convolutions:
# - it adds learnable offsets to these grid locations of the kernels making convolution flexible and spread out
# - used in object detection, segmentation, and image classification where objects can appear at different scales, poses, or orientations

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/deformed.png')
new_image = img.resize((580, 330))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=580x330>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/deformed1.png')
new_image = img.resize((780, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=780x200>
