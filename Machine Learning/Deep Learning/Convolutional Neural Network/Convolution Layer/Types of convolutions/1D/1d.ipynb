# %% [markdown]
# 1. [1D Convolution](#1d-convolution)

# %% [markdown]
# #### 1D Convolution:
# - here the filters used will be 1x1 kernels but the filters are 2x2
# - it is used for time series data

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/1d.png')
new_image = img.resize((450, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x150>
