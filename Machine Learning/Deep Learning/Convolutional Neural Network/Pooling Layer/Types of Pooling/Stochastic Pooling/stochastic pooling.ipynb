# %% [markdown]
# 1. [Stochastic Pooling](#stochastic-pooling)

# %% [markdown]
# #### Stochastic Pooling:
# - here by using stochastic pooling, first we transform the activation map values into probability value by normalizing it
# - then randomly choose the 1 sample value based on the probability values (the highest probability value will have the highest importance) its output values from using feature map matrix and pooling matrix is the probability/ values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/pooling.jpeg')
new_image = img.resize((630, 260))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=630x260>

# %%
a = 10
print(a)
# Out:
# 10
