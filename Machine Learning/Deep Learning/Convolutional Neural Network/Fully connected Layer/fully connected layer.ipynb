# %% [markdown]
# 1. [Fully Connected Layer](#fully-connected-layer)

# %% [markdown]
# #### Fully Connected Layer:
# - the fully connected layer is after performing the flattening of the pooled feature map
# - the fully connected layer is the same as fully connected ANN.

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/complete_cnn.jpg')
new_image = img.resize((800, 430))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x430>
