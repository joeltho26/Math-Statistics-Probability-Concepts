# %% [markdown]
# 1. [Same Padding](#same-padding)

# %% [markdown]
# #### Same Padding:
# - here in same padding, we notice that when we use filters to generate the feature or activation map, the size of feature map matrix is the same as the input matrix

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/pad.png')
new_image = img.resize((500, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=500x300>
