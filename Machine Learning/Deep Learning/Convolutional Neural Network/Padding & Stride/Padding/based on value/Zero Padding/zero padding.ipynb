# %% [markdown]
# 1. [Zero Padding](#zero-padding)

# %% [markdown]
# #### Zero Padding:
# - here in zero padding, we use zero values in padding of the input matrix

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/value.png')
new_image = img.resize((750, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=750x300>
