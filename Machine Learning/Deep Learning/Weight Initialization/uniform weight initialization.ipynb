# %% [markdown]
# 1. [Uniform Weight Initialization](#uniform-weight-initialization)

# %% [markdown]
# #### Uniform Weight Initialization:
# - the weight values are chosen from the uniform distribution
# - fan_in and fan_out are the number of input and output of the neural network

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/uniform.png')
new_image = img.resize((390, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=390x250>
