# %% [markdown]
# 1. [Graph Embeddings](#graph-embeddings)

# %% [markdown]
# #### Graph Embeddings:
# - it is a specific type of embedding
# - translate complex graphs into a fixed length vectors
#
# Note:
# - Embedding:
#     - is a process of translating high dimensional vectors (complex data) into low dimensional space (numerical format that machines understand) i.e. mapping complex data into a fixed length vector or matrix which capturing the relationship and features while reducing the dimensionality

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/graph.png')
new_image = img.resize((650, 450))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=650x450>
