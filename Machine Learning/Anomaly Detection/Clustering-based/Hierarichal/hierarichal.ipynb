# %% [markdown]
# 1. [Hierarichal clustering](#hierarichal-clustering)

# %% [markdown]
# #### Hierarichal clustering:
# - it is also used to check for outliers
# - it is very similar to the general hierarichal clustering technique which uses agglomerative approach
# - we can notice the anomalies in the data by visualizing the dendograms and see the cluster or datapoints which have greater vertical cluster distance because outliers are generally considered to be rare and distinct
# - or we can see the singleton clusters that remains isolated until the very end

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/1.png')
new_image = img.resize((600, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>
