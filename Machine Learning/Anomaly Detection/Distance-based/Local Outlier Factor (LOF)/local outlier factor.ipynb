# %% [markdown]
# 1. [Local Outlier Factor](#local-outlier-factor)

# %% [markdown]
# #### Local Outlier Factor:
# - used to detect anomaly or outlier
# - used to identify local outliers

# %% [markdown]
# - O3 => global outlier
#     - use distance based metrics
# - O1 => local outlier
#     - use density based algorithms

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/step1.png')
new_image = img.resize((600, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x300>

# %% [markdown]
# - calculate the reachability distance from all the neighbors to a given point

# %% [markdown]
# - calculate the local reachability distance of the point

# %% [markdown]
# - calculate the LOF score of the point using local reachability of its neighbors and the point itself
