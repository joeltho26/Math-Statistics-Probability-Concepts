# %% [markdown]
# 1. [Z-score](#z-score)

# %% [markdown]
# #### Z-score:
# - it is used identify outliers
# - the z score tells us who many standard deviation away is the data point from its mean
# - we consider the z-score greater than 3 generally associated with outliers

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/1.png')
new_image = img.resize((200, 130))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x130>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/2.png')
new_image = img.resize((370, 190))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=370x190>
