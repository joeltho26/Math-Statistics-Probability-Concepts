# %% [markdown]
# 1. [XgBoost - Regression](#XgBoost---Regression)

# %% [markdown]
# #### XgBoost - Regression:
# - designed to use for large, complicated and complex datasets
# - uses similarity score and information gain to build the tree
# - use γ to prune the trees
# - use α as learning rate
# - use λ as regularization parameter
# - 0.5 constant is chosen as the output of 1st weak learner (base model)

# %% [markdown]
# - mathematically, the loss function for xgboost regression as shown below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function_1.png')
new_image = img.resize((180, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=180x90>

# %% [markdown]
# - consider, we are comparing one of the feature from dataset (dosage) with drug effectiveness.
#     - we also have other features as Age and Sex
# - both the feature and the output are continuous numerical values
# - at first irrespective of classification or regression, we choose the predicted drug effectiveness as 0.5
# - the loss function for the base model with prediction of 0.5

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function3.png')
new_image = img.resize((580, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=580x90>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function4.png')
new_image = img.resize((240, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=240x90>

# %% [markdown]
# - now calculate the residuals i.e. observed values - predicted value (0.5)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/residual_reg.png')
new_image = img.resize((280, 360))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=280x360>

# %% [markdown]
# - we build the xgboost tree which is different from the regular regression decision tree using the similarity score & Information Gain
# - similarity score = (Σ(Residuals)^2)/(N + λ)
#     - N = Number of Residuals
#     - λ = regularization parameter

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/similarity_score.png')
new_image = img.resize((540, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=540x100>

# %% [markdown]
# - Before calculating the similarity score, we peform discretization by taking the first two values w.r.t drug dosage (feature) and take their average to perform the split
#     - value = 15

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/similarity_reg.png')
new_image = img.resize((260, 280))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=260x280>

# %% [markdown]
# - now, we calculate the similarity score for feature Dosage (root, intermediate nodes i.e. leaf nodes in this example)
#     - calculate the similarity score for root (λ=0) = (-10.5+6.5+7.5-7.5)^2/4+0 => 4
#     - calculate the similarity score for internal node 1 (λ=0) = (-10.5)^2/1 => 110.25
#     - calculate the similarity score for internal node 2 (λ=0) = (6.5)^2/3 => 14.08
# - now, calculate the information gain
#     - Information Gain(Dosage) = SS(node1) + SS(node2) - SS(root) = 124.33 - 4 => 120.33

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/similarity_score_root.png')
new_image = img.resize((340, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=340x200>

# %% [markdown]
# - likewise, now, we repeat the discretization process for the next two values i.e. 2nd and 3rd values and their average
#     - value = 22.5

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/similarity_reg2.png')
new_image = img.resize((260, 280))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=260x280>

# %% [markdown]
# - now, we calculate the similarity score for feature Dosage (root, intermediate nodes i.e. leaf nodes in this example)
#     - calculate the similarity score for root (λ=0) = (-10.5+6.5+7.5-7.5)^2/4+0 => 4
#     - calculate the similarity score for internal node 1 (λ=0) = (-10.5+6.5)^2/2 => 8
#     - calculate the similarity score for internal node 2 (λ=0) = (7.5-7.5)^2/3 => 0
# - now, calculate the information gain
#     - Information Gain(Dosage) = SS(node1) + SS(node2) - SS(root) = 8 - 4 => 4

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/similarity_score_node_1.png')
new_image = img.resize((340, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=340x200>

# %% [markdown]
# - likewise, now, we repeat the discretization process for the next two values i.e. 3rd and 4th values and their average
#     - value = 30

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/similarity_reg3.png')
new_image = img.resize((260, 280))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=260x280>

# %% [markdown]
# - now, we calculate the similarity score for feature Dosage (root, intermediate nodes i.e. leaf nodes in this example)
#     - calculate the similarity score for root (λ=0) = (-10.5+6.5+7.5-7.5)^2/4+0 => 4
#     - calculate the similarity score for internal node 1 (λ=0) = (-10.5+6.5+7.5)^2/3 => 4.08
#     - calculate the similarity score for internal node 2 (λ=0) = (-7.5)^2/1 => 56.25
# - now, calculate the information gain
#     - Information Gain(Dosage) = SS(node1) + SS(node2) - SS(root) = 4.08 + 56.25 - 4 => 56.33

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/similarity_score_node_2.png')
new_image = img.resize((340, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=340x200>

# %% [markdown]
# - now, comparing all the information gain calculated for all the three splits and choosing the one with the highest information gain value
# - now compare the same with other features as well and calculate the information gain
#     - If there is a categorical feature with binary category, we can split the root node into 2 internal nodes
#         - calculate the similarity score for each categories and also calculate the information gain
#     - If there is a categorical feature with more than 2 categories, we still perform binary split by merging the groups together
# - considering that the feature dosage had the highest information gain among all the features and it is considered as the root node
# - likewise, we start building the tree until its fully developed

# %% [markdown]
# - Once the tree is built, the respective loss function is shown as below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function.png')
new_image = img.resize((450, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x100>

# %% [markdown]
# - consider the λ = 0 with regards to the loss function, the right term is 0 and removed

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function5.png')
new_image = img.resize((320, 110))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=320x110>

# %% [markdown]
# - now if we consider the output of the tree as 0 and the corresponding loss function = 104.4

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function2.png')
new_image = img.resize((420, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=420x100>

# %% [markdown]
# - now, if we consider the output value = -1

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function6.png')
new_image = img.resize((420, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=420x100>

# %% [markdown]
# - now, if we consider the output value = 1

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function7.png')
new_image = img.resize((420, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=420x100>

# %% [markdown]
# - now, we plot the scatter plot graph for loss function vs output value and find the loss function value the lowest for output value = 1

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function_output_value.png')
new_image = img.resize((450, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x300>

# %% [markdown]
# - as we keep plugging in the values for different output values, we get a gradient descent curve

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function_output_value1.png')
new_image = img.resize((450, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x300>

# %% [markdown]
# - now, we can increase the value of λ from 0
# - As we increase the λ value in the similarity score, we get a lower score
#     - especially if we have many residuals associated to the node and with the increase in lambda value, the decrease in similarity score is less compared to having lower number of residuals
# - w.r.t loss function,
#     - as we increase the lambda function, the output values get closer to zero i.e. it reduces the similarity scores and the respective gain as shown below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/lambda_values.png')
new_image = img.resize((480, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=480x300>

# %% [markdown]
# - the output value for the terminal regions of regression is calculated via 2nd order taylor polynomial function

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor.png')
new_image = img.resize((600, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x100>

# %% [markdown]
# - the taylor function 1st order derivative and 2nd order derivative is replaced with "g" & "h" respectively
#     - h => hessian

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor_modify.png')
new_image = img.resize((600, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x150>

# %% [markdown]
# - now we expand the loss function w.r.t xgboost regression

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function.png')
new_image = img.resize((500, 110))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x110>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function8.png')
new_image = img.resize((400, 210))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x210>

# %% [markdown]
# - now, plug in the 2nd order taylor approximation into the above function

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function9.png')
new_image = img.resize((480, 210))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=480x210>

# %% [markdown]
# - re-arranging the above formula

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function10.png')
new_image = img.resize((780, 110))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=780x110>

# %% [markdown]
# - we need to perform the below 3 steps to find the optimal value as output value for the terminal nodes

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function_3steps.png')
new_image = img.resize((780, 410))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=780x410>

# %% [markdown]
# - after peforming the 1st and 2nd order derivative w.r.t output value "O", we get the below formula for O value

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/output_reg_loss.png')
new_image = img.resize((380, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x100>

# %% [markdown]
# - the output value calculated from the nodes is also represented as below
#     - the output residuals from the built tree
#         - = (Σ(Residuals))/(N + λ)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/output_reg.png')
new_image = img.resize((600, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x100>

# %% [markdown]
# - now, we can prune the trees via γ value
#     - e.g:
#         - prune trees if Information Gain - γ results in -ve value
#             - we keep prunning trees until we meet a +ve value
#         - do not prune trees if Information Gain - γ results in +ve value
#             - if we have +ve value for internal nodes but the root node is -ve, we do not prune the tree
# - we can also limit the building of the tree upto a certain depth level, default depth levels = 6
# - the minimum number of residuals in each leaves is determined by calculating the cover value
#     - the cover value = N i.e. number of residuals
#         - default cover value = 1
# - now, while prediction
#     - since the trees are connected in series, we add the outputs from each tree
#         - constant (0.5) + α (learning rate=0.3, between 0-1) * output leaf as shown below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/prediction.png')
new_image = img.resize((700, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=700x400>

# %% [markdown]
# - we compare the initial prediction and the prediction after the first tree and find the decrease in residuals
#     - one step at a time to get better prediction

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/prediction_compare.png')
new_image = img.resize((600, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x400>

# %% [markdown]
# Optimizations of Xgboost:
# - approximate greedy algorithm:
#     - uses quantiles to choose the best split instead of going through each instance to find the split threshold
#         - approximately uses 33 quantiles
#             - parallel learning
#             - weighted quantile sketch

# %% [markdown]
# - parallel learning
#     - consider the large dataset is broken into several pieces of data and stored in different systems connected in the same network

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/optimization2.png')
new_image = img.resize((800, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x300>

# %% [markdown]
# - weighted quantile sketch
#     - when required, the data is gathered from all the systems and forms a histogram
#     - then, the histogram is split into various quantiles
#     - since quantiles supposed to have equal number of observations in each of it
#         - but the histogram which is split earlier part of xgboost doesnt have equal observation, therefore, we take the weighted quantiles i.e. sum of weights of each quantile is the same and it is calculated via cover value
#         - weight is the 2nd derivative of the loss function
#     - therefore for classification & Regression
#         - Classification:
#             - weight => p * (1-p)
#         - Regression:
#             - weight = N => 1

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/optimization3.png')
new_image = img.resize((300, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x200>

# %% [markdown]
# - sparsity aware split finding:
#     - when we have a dataset with few missing values along with the records with all the values present
#     - we create seperate table for records with missing values and without missing values w.r.t the feature we are trying to perform the split
#     - first, we split the tree based on non missing values and then while performing calculation the gain on the left and the right, we add the residuals present for the missing values
#         - for splitting the tree via discretization for numerical values as followed in decision tree algorithms
#             - if its a large dataset, we would use quantiles for the split condition

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/optimization.png')
new_image = img.resize((600, 400))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x400>

# %% [markdown]
# - we choose the split for feature "dosage" with gain score the highest overall
#     - ensures that the missing values of the feature are assigned to a specific left or right node based on the split condition with highest gain score

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gain.png')
new_image = img.resize((390, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=390x150>

# %% [markdown]
# - Cache Aware Access:
#     - the gradients and hessians is calculated in cache memory for similarity scores and output values
# - Blocks out of core computation (Sharding):
