# %% [markdown]
# 1. [Gradient Boosting](#gradient-boosting)

# %% [markdown]
# #### Gradient Boosting:
# - it a type of ensemble technique, were it connects the decision trees in series
# - consider a dataset with 3 features and 1 binary target variable

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/dataset_class1.png')
new_image = img.resize((330, 350))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=330x350>

# %% [markdown]
# - Mathematically, we need a differentiable loss function for classification
# - we need a plot to visualize the loss function
#     - prediction probability (Yes) = 4/6 = 2/3 = 0.67

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_func_class.png')
new_image = img.resize((390, 310))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=390x310>

# %% [markdown]
# - we need to calculate the Log(Likelihood of the observed data given the prediction)
#     - Log(Likelihood of the observed data given the prediction) formula shown below
#         - p => predicted probability
#         - yi => observed value

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_likelihood.png')
new_image = img.resize((450, 110))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x110>

# %% [markdown]
# - Log(Likelihood of the observed data given the prediction) = log(0.67) + log(0.67) + log(0.33) + log(0.33) + log(0.67) + log(0.67)
# - we know that large log(likelihood), better the prediction
# - Therefore, we use log likelihood as the loss function, therefore smaller values represent better fitting models
#     - so we append a minus before the log likelihood formula called the negative log likelihood

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_likelihood1.png')
new_image = img.resize((450, 110))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x110>

# %% [markdown]
# - since the loss function deals with 1 sample at a time, we remove the summation from the formula

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_likelihood2.png')
new_image = img.resize((450, 110))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x110>

# %% [markdown]
# - now we replace the y with observed in the formula above

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_likelihood3.png')
new_image = img.resize((580, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=580x100>

# %% [markdown]
# - now, we transform the negative log(likelihood) into log(odds) instead of predicted probability (p)
#     - at first, we take the negative sign inside the formula
#     - multiple log(1-p) with (1-observed)
#     - now combine observed
#     - now log(p)-log(1-p) => log(p/(1-p)) => log(odds)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_odds.png')
new_image = img.resize((680, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=680x300>

# %% [markdown]
# - now, we need to convert log(1-p) i.e. predicted probability into log(odds)
# - we know the p value below is derived from Logistic Regression on estimating parameters with maximum likelihood

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_odds3.png')
new_image = img.resize((1080, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=1080x100>

# %% [markdown]
# - now the log of division is transformed to subtraction as shown below
# - log(1) => 0
# - the final value of log(1-p) is shown below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_odds2.png')
new_image = img.resize((380, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x80>

# %% [markdown]
# - now we substitute the value of log(1-p) into the formula in step 4
#     - we notice the sign change
# - This is the final loss function for classification

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_odds4.png')
new_image = img.resize((640, 60))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=640x60>

# %% [markdown]
# - now we take 1st order derivative w.r.t log(odds) using chain rule

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_odds5.png')
new_image = img.resize((640, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=640x100>

# %% [markdown]
# - we notice that the derivative of the loss can be a function of log(odds) of function of predicted probability (p)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/loss_function_final.png')
new_image = img.resize((340, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=340x250>

# %% [markdown]
# - first, we calculate the log of odds to convert to probabilities using natural logarithm
#     - ln(odds=Yes) = ln(p/1-p) = ln(4/2) = ln(2) = 0.6931 = 0.7
#         - where odds = p/(1-p)
# - now convert the value into probabilities therefore subsititute the calculated log of odds into the sigmoid function
#     - sigmoid function: real numbers into maps probabilities (binary classification as shown below)
#         - Probability = 0.6667 = 0.7
#         - this is the probability value for all the records by the weak learner

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/logistic.png')
new_image = img.resize((140, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=140x80>

# %% [markdown]
# - softmax function: real numbers into maps probabilities (multiclass classification)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/softmax.png')
new_image = img.resize((190, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=190x120>

# %% [markdown]
# - after coverting the values from log(odds) to probability, calculate the residuals
#     - eg:
#         - Predicted (Yes) = 1
#         - Predicted (No) = 0
#         - Residual(predicted=Yes) = 1 - probability(Yes) = 1 - 0.7 = 0.3
#         - Residual(predicted=No) = 0 - probability(No) = 0 - 0.7 = -0.7
# - Mathematically, we take the first order derivative of the loss function along with the negative sign (-)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/residual1.png')
new_image = img.resize((390, 320))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=390x320>

# %% [markdown]
# - now, we build the tree as part of the training process
#     - we choose the number of leaf nodes needed for the tree
#         - most common (8-32 leaf nodes) but this example we choose 3 leaf nodes
#     - we create the terminal regions for the leaf nodes
#     - we also evaluate the gamma value for the terminal regions for the leaf nodes
# - now, we choose one record at a time and process the flow of the record in the tree until leaf node and the residual value is stored in the leaf node

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/tree_class.png')
new_image = img.resize((320, 270))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=320x270>

# %% [markdown]
# - while evaluating the gamma value for the termina regions by taking the first order derivative of gamma w.r.t Loss function, it very difficult
# - So we use Taylor 2nd order Polynomial equation to get the derivative of gamma

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/taylor.png')
new_image = img.resize((990, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=990x100>

# %% [markdown]
# - compare the 1st order derivative of gamma with taylor 2nd order polynomial equation and take the derivative of gamma
#     - since the first component of the taylor equation is not associated with gamma so its considered as constant and its removed
#     - we also notice the third component from the taylor series (1/2) is cancelled out when the gamma derivation is performed

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_class1.png')
new_image = img.resize((990, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=990x100>

# %% [markdown]
# - the final gamma value after derivation is evaluated
#     - numerator = negative of the derivative of the loss function
#     - denominator = second derivative of the loss function

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_class.png')
new_image = img.resize((390, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=390x250>

# %% [markdown]
# - now, sinc we know the loss function already, we substitute the values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_class2.png')
new_image = img.resize((390, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=390x200>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_class3.png')
new_image = img.resize((320, 170))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=320x170>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_class4.png')
new_image = img.resize((320, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=320x150>

# %% [markdown]
# - now, we evaluate the denominator of gamma w.r.t second derivative of log(odds) loss function

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_class5.png')
new_image = img.resize((620, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=620x90>

# %% [markdown]
# - now, we substitute the loss function already evaluated for the first derivative of log(odds)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_class6.png')
new_image = img.resize((620, 210))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=620x210>

# %% [markdown]
# - now, while performing the second derivative
#     - we notice the observed component is considered as constant since there is no log(odd) variable
#     - the right side component is a little complicated, so we use product rule
#     - a` is the derivative term of a
#     - b` is the derivative term of b

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/product_rule.png')
new_image = img.resize((320, 60))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=320x60>

# %% [markdown]
# - the output of gamma denominator (2nd derivative of the loss function) using product rule

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_class7.png')
new_image = img.resize((1020, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=1020x80>

# %% [markdown]
# - using algebra to simplify the above equation
#     - we re-arrange the equation as below
#     - we multiply the second term with (1+e^(log(odds))) both numerator and denominator

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/second_derivative.png')
new_image = img.resize((1020, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=1020x100>

# %% [markdown]
# - now, we add the terms together

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/second_derivative1.png')
new_image = img.resize((1020, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=1020x100>

# %% [markdown]
# - now, we split the denominator into 2 terms

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/second_derivative2.png')
new_image = img.resize((420, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=420x120>

# %% [markdown]
# - now the above equation is split

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/second_derivative3.png')
new_image = img.resize((420, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=420x120>

# %% [markdown]
# - the final term (denominator of gamma) is shown below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/second_derivative_final.png')
new_image = img.resize((250, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x100>

# %% [markdown]
# - now, we know the first term is p and the second term is (1-p)
# - now going back to the gamma value
#     - gamma value = Residual/p * (1-p)
#         - γ11 = = 0.67/0.67(1-0.67) => 3.03
#             - p = e^(log(odds))/(1+e^(log(odds))) => 0.67
#                 - log(odds) => log(4/2) => 0.69

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_value.png')
new_image = img.resize((250, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x120>

# %% [markdown]
# - likewise, for the other leaf node, we calculate the gamma value
#     - repeat the same procedure starting from choosing the taylor 2nd order polynomial instead of taking the 1st order derivative of the loss function w.r.t gamma
#         - taking the product rule
#         - chain rule

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_value2.png')
new_image = img.resize((450, 190))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=450x190>

# %% [markdown]
# - after evaluate the gamma value numerator and denominator, re-define the gamma value

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/gamma_value3.png')
new_image = img.resize((350, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x120>

# %% [markdown]
# - γ21 = = 0.33-0.67/0.67(1-0.67) + 0.67(1-0.67) => 0.77
#     - p = e^(log(odds))/(1+e^(log(odds))) => 0.67
#         - log(odds) => log(4/2) => 0.69
#
# - γ31 = = 0.33+0.33+0.33/0.67(1-0.67) + 0.67(1-0.67) + 0.67(1-0.67) => 1.49
#     - p = e^(log(odds))/(1+e^(log(odds))) => 0.67
#         - log(odds) => log(4/2) => 0.69

# %% [markdown]
# - since the predictions are in the log of the odds and the leaf in the tree is derived from probabilities, we convert the leaf probabilities to log(odds)
#     - Leaf Probability (-0.67) = -0.67 / (0.67) * (1-0.67) = -3.3
#     - Leaf Probability (0.33,-0.67) = -0.67 + 0.3 / (((0.67) * (1-0.67)) + ((0.67) * (1-0.67))) = -1
#     - Leaf Probability (0.33,0.33,0.33) = 0.3 + 0.3 + 0.3 / (((0.67) * (1-0.67)) + ((0.67) * (1-0.67)) + ((0.67) * (1-0.67))) = 1.4

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/prob_to_residual.png')
new_image = img.resize((490, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=490x100>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/tree_class_updated.png')
new_image = img.resize((590, 220))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=590x220>

# %% [markdown]
# - now if we calculate the log of the odds for the first record
#     - eg: log(odds|Record 1) = 0.7 + 0.8 * 1.4 = 1.8

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/log_of_odds_eg.png')
new_image = img.resize((680, 390))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=680x390>

# %% [markdown]
# - now convert the new log(odds) = 1.8 into probabilities
#     - Prob(1.8) = 0.9
# - likewise, we repeat the same for all the records
# - again, we repeat the step of calculating the residuals
# - again, converting the residuals into log(odds)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/updated_tree2.png')
new_image = img.resize((480, 360))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=480x360>

# %% [markdown]
# - we repeat the procedure over again until the number of trees specified is achieved
