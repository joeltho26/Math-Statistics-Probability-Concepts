# %% [markdown]
# 1. [Likelihood](#likelihood)

# %% [markdown]
# #### Likelihood:
# - evaluating the ```model parameters``` given the observed data
# - the distribution parameters 'μ' mean & 'σ' standard deviation are varying i.e. model parameters are changing with fixed observation data

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/likelihood1.png')
new_image = img.resize((550, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=550x250>
