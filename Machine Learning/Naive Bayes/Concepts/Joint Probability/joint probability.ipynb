# %% [markdown]
# 1. [Joint Probability](#joint-probability)

# %% [markdown]
# #### Joint Probability:
# - ```likelihood``` of two or more events happening at the same time

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/joint-probability.png')
new_image = img.resize((130, 50))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=130x50>
