# %% [markdown]
# 1. [Conditional Probability](#conditional-probability)

# %% [markdown]
# #### Conditional Probability:
# - the ```likelihood``` of an event B occuring given the event A has already occured
# - the numerator is a ```joint probability```

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/conditional1.png')
new_image = img.resize((230, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=230x100>
