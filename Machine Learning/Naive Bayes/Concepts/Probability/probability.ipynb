# %% [markdown]
# 1. [Probability](#probability)

# %% [markdown]
# #### Probability:
# - used in prediction of an output label of a model given certain model parameters i.e. fixed 'μ' mean & 'σ' standard deviation distribution parameters

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/probability.png')
new_image = img.resize((550, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=550x250>
