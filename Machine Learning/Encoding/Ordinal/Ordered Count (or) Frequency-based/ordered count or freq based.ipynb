# %% [markdown]
# 1. [Ordered Count/Frequency-based Encoding](#ordered-countfrequency-based-encoding)

# %% [markdown]
# #### Ordered Count/Frequency-based Encoding:
# - it encodes the categorical variable labels
# - calculate the ```count``` of each label
# - then, ```probability``` of each label is calculated and an order is assigned
#     - divide the ```count of each label``` with the ```overall count``` (rows) of dataset
# - if ```2``` labels having ```same frequency```,
#
#     - ```lexicographical order```
#
#     - ```ordered mean encoding``` (alternate approach)
#
#     - ```introduce random noise```

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/ordered-count-frequency.png')
new_image = img.resize((750, 285))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=750x285>
