# %% [markdown]
# 1. [Weight of Evidence & Information Value Encoding](#weight-of-evidence--information-value-encoding)

# %% [markdown]
# #### Weight of Evidence & Information Value Encoding:
# - we transform the categorical feature into numerical values
# - used in binary classification

# %% [markdown]
# Dataset:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/weight_data.png')
new_image = img.resize((250, 650))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x650>

# %% [markdown]
# create contingency table for default "1" & "0" w.r.t categories of education feature

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/weight_data2.png')
new_image = img.resize((600, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=600x250>

# %% [markdown]
# Calculate the Percentage of Default 1 and Default 0 for Each Category and Overall

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/weight_data3.png')
new_image = img.resize((800, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x250>

# %% [markdown]
# Calculate Weight of Evidence (WoE) for Each Category

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/weight_data4.png')
new_image = img.resize((800, 380))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x380>

# %% [markdown]
# Handling 0 values
# - having 0 values will lead to undefined issues while calculating the weight of evidence
# - as a solution, we add a small constant i.e. 0.5 in both default 1 (events) and default 0 (non-events)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/weight_data5.png')
new_image = img.resize((800, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x150>

# %% [markdown]
# Calculate Information Value (IV) for the Feature

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/weight_data6.png')
new_image = img.resize((800, 530))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x530>

# %% [markdown]
# the encoded values for categories in the categorical feature is the WOE value for the categories of the categorical feature
