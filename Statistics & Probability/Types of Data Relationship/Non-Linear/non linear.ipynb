# %% [markdown]
# 1. [Non Linear Relationship](#non-linear-relationship)

# %% [markdown]
# #### Non Linear Relationship:
# - ```not associated``` with ```constant rate of change``` and they can move in ```any direction``` either forward or backward
# - datapoints are ```scattered``` everywhere

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/nonlinear.jpg')
new_image = img.resize((530, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=530x250>
