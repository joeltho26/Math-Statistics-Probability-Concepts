# %% [markdown]
# 1. [Log Normal Distribution](#log-normal-distribution)

# %% [markdown]
# #### Log Normal Distribution:
# - the distribution is right skewed
# - applying log to the log normal distribution will result in normal distribution of data

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/lognormal.jpg')
new_image = img.resize((550, 240))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=550x240>
