# %% [markdown]
# 1. [Bayes Theorem](#bayes-theorem)

# %% [markdown]
# #### Bayes Theorem:
# - it used to identify the conditional probability of an event B given the event A has already occured
# - P(A|B) = posterior probability
# - P(A) = prior probability
# - P(B) = evidence
# - P(B|A) = likelihood

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bayes.png')
new_image = img.resize((400, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x250>
