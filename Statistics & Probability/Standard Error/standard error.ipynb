# %% [markdown]
# 1. [Standard Error](#standard-error)

# %% [markdown]
# #### Standard Error:
# - is a statistic that reveals how accurate the sample data represents the population data

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/standard-error.png')
new_image = img.resize((220, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x120>
