# %% [markdown]
# 1. [Correlation](#correlation)

# %% [markdown]
# #### Correlation:
# - a relationship between two variables but no proven cause and effect
# - 2 types of correlation
#     - positive correlation
#     - negative correlation

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/correlation.png')
new_image = img.resize((750, 350))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=750x350>
