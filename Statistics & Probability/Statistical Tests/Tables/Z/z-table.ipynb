# %% [markdown]
# 1. [Z-table](#z-table)

# %% [markdown]
# #### Z-table:
# - it is used to convert the calculated z-score into probabilities of observing a value

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/z-score_negative.png')
new_image = img.resize((750, 700))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=750x700>

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/z-score_positive.png')
new_image = img.resize((750, 700))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=750x700>
