# %% [markdown]
# 1. [Mann Whitney U or 2 sample Wilcoxon Rank Sum test](#mann-whitney-u-or-2-sample-wilcoxon-rank-sum-test)

# %% [markdown]
# #### Mann Whitney U or 2 sample Wilcoxon Rank Sum test:
# - used to compare the median of two independent groups
# - uses 1 categorical variable with 2 categories against 1 continuous variable or 2 different samples from same continuous variable

# %% [markdown]
# ##### Example:
# Question:
# - n1 = n2 = 10

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/mann_whitney_data.png')
new_image = img.resize((210, 430))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=210x430>

# %% [markdown]
# Answer:
# - Null Hypothesis: no change in the median
# - Alternate Hypothesis: change in the median
# - combine the score from both A & B and sort them in ascending order
#     - first append the score A and B one below the other and rank them from lowest to highest

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/combine.png')
new_image = img.resize((180, 530))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=180x530>

# %% [markdown]
# - calculate the sum of ranks for each group
#     - Sum of Ranks for Method A (R₁): 1 + 2 + 3 + 4 + 5 + 6 + 8 + 9.5 + 11 + 12.5 = 62
#     - Sum of Ranks for Method B (R₂): 7 + 9.5 + 12.5 + 14 + 15 + 16 + 17 + 18 + 19 = 128
#
# - calculate the two U statistics value and choose the lower value among the both
#     - U1 & U2
#         - U1 = 93
#         - U2 = 27 (chosen)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/mann_whitney.png')
new_image = img.resize((340, 170))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=340x170>

# %% [markdown]
# - calculate the critical value
#     - using the sample sizes (n1=n2=10) and significance level (0.05)
#     - critical value = 23
# - Since the statistic value (27) > critical value (23). Then, we reject the null hypothesis and say there is a difference between the two medians of the samples
