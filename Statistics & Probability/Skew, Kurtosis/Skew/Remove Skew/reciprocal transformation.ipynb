# %% [markdown]
# 1. [Reciprocal or Inverse Transformation - Gaussian](#reciprocal-or-inverse-transformation---gaussian)

# %% [markdown]
# #### Reciprocal or Inverse Transformation - Gaussian:
# - it is used to reduce the skewness and kurtosis of data
# - the values are transformed by the taking the inverse of each
# - helps in outlier detection

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/reciprocal.png')
new_image = img.resize((180, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=180x120>
