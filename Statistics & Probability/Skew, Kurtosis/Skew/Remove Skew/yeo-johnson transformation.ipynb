# %% [markdown]
# 1. [Yeo Johnson Transformation - Gaussian](#yeo-johnson-transformation---gaussian)

# %% [markdown]
# #### Yeo Johnson Transformation - Gaussian:
# - reduces skewness and kurtosis of data
# - it is an extension of box cox
# - it works with negative and zero values also
# - helps in outlier detection

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/yeo.png')
new_image = img.resize((430, 150))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=430x150>
