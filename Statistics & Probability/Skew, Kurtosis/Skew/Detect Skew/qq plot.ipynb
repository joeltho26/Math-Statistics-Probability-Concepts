# %% [markdown]
# 1. [Q-Q Plot](#q-q-plot)

# %% [markdown]
# #### Q-Q Plot:
# - it is a plot used to compare skewness in a dataset
# - compares the sample normal distribution quantiles from a dataset vs the theoritical standard normal distribution quantile
# - its often used with numerical continuous variable

# %% [markdown]
# - Q-Q Plot with no skew:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/no_skew_qq.png')
new_image = img.resize((380, 270))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x270>

# %% [markdown]
# - Q-Q Plot with positive/right skew:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/right_skew_qq.png')
new_image = img.resize((380, 270))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x270>

# %% [markdown]
# - Q-Q Plot with negative/left skew:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/left_skew_qq.png')
new_image = img.resize((380, 270))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x270>
