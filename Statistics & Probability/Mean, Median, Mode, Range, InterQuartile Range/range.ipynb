# %% [markdown]
# 1. [Range](#range)

# %% [markdown]
# #### Range:
# - denoted by the difference between maximum value and minimum value for a variable

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/range.png')
new_image = img.resize((620, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=620x80>
