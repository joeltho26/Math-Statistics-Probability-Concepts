# %% [markdown]
# 1. [T Statistic or Test Statistic](#t-statistic-or-test-statistic)

# %% [markdown]
# #### T Statistic or Test Statistic:
# - value calculated from sample data to reject or accept the null hypothesis

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/test-statistic.png')
new_image = img.resize((250, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x120>

# %% [markdown]
# - β^ = estimator of parameter (sample mean)
# - β0 = non-random known constant (hypothesized mean)
# - SE(β^) = Standard Error of β^

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/standard-error.png')
new_image = img.resize((250, 120))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x120>
