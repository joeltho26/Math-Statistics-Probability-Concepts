# %% [markdown]
# 1. [Quintile](#quntile)

# %% [markdown]
# #### Quntile:
# - subset of quantiles which has ```5 equally distributed``` parts

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/quintile.jpg')
new_image = img.resize((620, 190))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=620x190>
