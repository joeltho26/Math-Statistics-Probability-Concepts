# %% [markdown]
# 1. [Decile](#decile)

# %% [markdown]
# #### Decile:
# - it a subset of quantiles which have ```10 equally distributed``` parts

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/decile.jpg')
new_image = img.resize((520, 290))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=520x290>
