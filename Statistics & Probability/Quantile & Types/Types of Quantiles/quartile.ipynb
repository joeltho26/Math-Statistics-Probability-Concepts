# %% [markdown]
# 1. [Quartile](#quartile)

# %% [markdown]
# #### Quartile:
# - it is a subset of quantile which has ```4 equal``` parts

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/quartile.jpg')
new_image = img.resize((520, 290))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=520x290>
