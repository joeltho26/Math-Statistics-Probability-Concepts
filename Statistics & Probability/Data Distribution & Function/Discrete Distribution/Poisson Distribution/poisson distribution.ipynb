# %% [markdown]
# 1. [Poisson Distribution](#poisson-distribution)

# %% [markdown]
# #### Poisson Distribution:
# - discrete probability distribution
# - describes about the probability of independent event happens K times for a fixed period of time

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/poisson1.png')
new_image = img.resize((250, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x100>
