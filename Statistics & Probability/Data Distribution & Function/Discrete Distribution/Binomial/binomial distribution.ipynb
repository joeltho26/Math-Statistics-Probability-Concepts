# %% [markdown]
# 1. [Binomial Distribution](#binomial-distribution)

# %% [markdown]
# #### Binomial Distribution:
# - discrete probability function
# - probability of number of success from n independent bernoulli trials
# - PDF for binomial distribution function as shown below

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/binomial.gif')
new_image = img.resize((480, 250))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=480x250>
