# %% [markdown]
# 1. [Poisson Distribution](#poisson-distribution)

# %% [markdown]
# #### Poisson Distribution:
# - it is the discrete distribution to explains the probability of an independent event ocurring at a given time

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/poisson.png')
new_image = img.resize((580, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=580x100>
