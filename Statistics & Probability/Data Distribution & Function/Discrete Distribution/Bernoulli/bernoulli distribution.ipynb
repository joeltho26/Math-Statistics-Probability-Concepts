# %% [markdown]
# 1. [Bernoulli Distribution](#bernoulli-distribution)

# %% [markdown]
# #### Bernoulli Distribution:
# - it called as binary distribution
# - models two possible outcomes from an single event, with a fixed probability of success
#     - Success: p
#     - Failure: q = 1-p
# - eg: coin toss
# - mean: p
# - variance: pq
# - standard deviation: √pq
# - probability distribution function (PDF) of bernoulli distribution shown below
#     - Failure: x=0
#     - Success: x=1

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bernoulli.png')
new_image = img.resize((270, 45))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=270x45>
