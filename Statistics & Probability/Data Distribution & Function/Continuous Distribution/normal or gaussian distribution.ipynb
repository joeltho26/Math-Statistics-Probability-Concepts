# %% [markdown]
# 1. [Normal Distribution](#normal-distribution)

# %% [markdown]
# #### Normal Distribution:
# - mean & std can be any value
# - the bell curve is symmetric on both sides
# - the empirical rule,
#     - 68% of data lie within 1σ
#     - 95% of data lie within 2σ
#     - 99.7% of data lie within 3σ

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/normal.png')
new_image = img.resize((580, 300))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=580x300>
