# %% [markdown]
# 1. [Variable Types](#variable-types)

# %% [markdown]
# #### Variable:
# - provides a quantitative measure about any feature such as height, grades, city, country, pincode, etc
# - there are 2 types:
#     - ```Numerical```
#     - ```Categorical```

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/types1.png')
new_image = img.resize((650, 200))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=650x200>
