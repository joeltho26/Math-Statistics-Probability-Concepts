# %% [markdown]
# 1. [Density Plot](#density-plot)

# %% [markdown]
# #### Density Plot:
# - it plots the distribution of data similar as the normal distribution curve
# - it uses the probability distribution function via kernal density estimation to create the density plot (normal distribution curve)
# - it is used to identify skewness of the data distribution
# - it plots for only continuous numerical values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/density.png')
new_image = img.resize((440, 280))
display(new_image)
# Out:
# <PIL.Image.Image image mode=P size=440x280>
