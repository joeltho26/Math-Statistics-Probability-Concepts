# %% [markdown]
# 1. [Kelly's Coefficient](#kellys-coefficient)
# 2. [Kelly's Coefficient for skewness - Percentile](#kellys-coefficient-for-skewness---percentile)
# 3. [Kelly's Coefficient for skewness - Decile](#kellys-coefficient-for-skewness---decile)

# %% [markdown]
# #### Kelly's Coefficient:
# - it is used to identify strength and the direction of skewness
# - uses percentiles or deciles to measure skewness
# - used for numerical continuous data

# %% [markdown]
# #### Kelly's Coefficient for skewness - Percentile:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/percentile.png')
new_image = img.resize((380, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=380x90>

# %% [markdown]
# - P50 => Median value

# %% [markdown]
# #### Kelly's Coefficient for skewness - Decile:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/decile.png')
new_image = img.resize((300, 90))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x90>
