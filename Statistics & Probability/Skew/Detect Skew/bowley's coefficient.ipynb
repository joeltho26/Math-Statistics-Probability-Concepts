# %% [markdown]
# 1. [Bowley's Coefficient](#bowleys-coefficient)

# %% [markdown]
# #### Bowley's Coefficient:
# - it is used to identify strength and the direction of skewness
# - uses quartiles to measure skewness
# - used for continuous numerical data

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/bowley.png')
new_image = img.resize((200, 100))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x100>

# %% [markdown]
# - M => Median
