# %% [markdown]
# 1. [One group](#one-group)

# %% [markdown]
# #### One group:
# Parametric:
# - One sample t test
# - one sample z test
#
# Non-parametric:
# - Wilcoxon signed-rank test
# - sign test
# - One-Sample Kolmogorov-Smirnov Test
#     - compares the distribution of a single sample to a specified theoretical distribution
# - one-sample runs test

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/one-group.png')
new_image = img.resize((980, 480))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=980x480>
