# %% [markdown]
# 1. [Square Root Tramsformation - Gaussian](#square-root-tramsformation---gaussian)

# %% [markdown]
# #### Square Root Tramsformation - Gaussian:
# - it is used to normalize the data by taking the square root of all the values
# - reduces the skewness and kurtosis of data
# - reduces the impact of outliers

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/squareroot.png')
new_image = img.resize((180, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=180x80>
