# %% [markdown]
# 1. [Exponential Transformation - Gaussian](#exponential-transformation---gaussian)

# %% [markdown]
# #### Exponential Transformation - Gaussian:
# - reduces skewness and kurtosis of data
# - e to the power value is applied to the data for transformation
#     - e value = 2.718 (Euler's number)
# - reduces the impact of outliers
# - while using in pratical use cases:
#     define e^x = x**(1/1.12)

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/exp.png')
new_image = img.resize((240, 80))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=240x80>
