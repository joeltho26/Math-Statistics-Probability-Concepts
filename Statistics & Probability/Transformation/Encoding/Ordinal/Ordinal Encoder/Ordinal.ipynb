# %% [markdown]
# 1. [Ordinal Encoder](#ordinal-encoder)

# %% [markdown]
# #### Ordinal Encoder:
# - encodes the value and inherits an order to it
# - the order of the labels are given manually

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/ordinal.png')
new_image = img.resize((250, 160))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=250x160>
