# %% [markdown]
# 1. [Mean Target-guided Encoding](#mean-target-guided-encoding)

# %% [markdown]
# #### Mean Target-guided Encoding:
# - the encoded values are based on the ```probability``` of each ```categorical``` labels w.r.t ```output class``` labels

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/mean.png')
new_image = img.resize((550, 270))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=550x270>
