# %% [markdown]
# 1. [Backward Difference Contrast Encoding](#backward-difference-contrast-encoding)

# %% [markdown]
# #### Backward Difference Contrast Encoding:
# - ```each label``` in ```categorical``` variable creates a ```new column``` except 1 which is the ```reference``` column
#     - K-1 columns for K labels in a categorical variable

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/backward.png')
new_image = img.resize((590, 195))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=590x195>
