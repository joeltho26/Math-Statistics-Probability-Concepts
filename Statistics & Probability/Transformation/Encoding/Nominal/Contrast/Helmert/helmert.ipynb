# %% [markdown]
# 1. [Helmert Encoding](#helmert-encoding)

# %% [markdown]
# #### Helmert Encoding:

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/helmert.png')
new_image = img.resize((460, 180))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=460x180>
