# %% [markdown]
# 1. [Hash Encoding](#hash-encoding)

# %% [markdown]
# #### Hash Encoding:
# - uses a ```hash function``` to encode the values
# - the ```hashed value``` is then reduced to a ```fixed value``` using ```modulo operator```
# - the attained ```fixed value``` is transformed into ```binary``` values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/hash.png')
new_image = img.resize((500, 380))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=500x380>
