# %% [markdown]
# 1. [Label Encoding](#)

# %% [markdown]
# #### Label Encoding:
# - ```encodes``` the categorical labels into values

# %%
from PIL import Image 
from IPython.display import display

img = Image.open('images/label.jpg')
new_image = img.resize((440, 270))
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=440x270>
